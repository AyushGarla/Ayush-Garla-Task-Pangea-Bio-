# %%
import pandas as pd
import numpy as np
uses_data = pd.read_csv("F:\\MS\\SRH study\\IV sem\\INT\\Datasets 2023\\naeb\\data\\naeb_dump\\uses.csv")
uses_data
# Out:
#           id  species  tribe  source pageno  use_category  use_subcategory  \
# 0          1        1     21      53    197             2             25.0
# 1          2        1     21      53    197             2             14.0
# 2          3        1     21      53    197             2            123.0
# 3          4        1     21      53    197             2             49.0
# 4          5        1     86     166    152             2             69.0
# ...      ...      ...    ...     ...    ...           ...              ...
# 44686  44687     4260    122      53    200             1              NaN
# 44687  44688     4260    166     101     89             1              NaN
# 44688  44689     4260    166     101     89             3             28.0
# 44689  44690     4260    181      14     82             1              NaN
# 44690  44691     4260    215      23     77             1             86.0
#
#                                                    notes  \
# 0      Liquid pitch mixed with mountain goat tallow a...
# 1           Infusion of bark taken for stomach ailments.
# 2      Liquid pitch mixed with mountain goat tallow a...
# 3               Infusion of bark taken for tuberculosis.
# 4                 Bark and other plants used as a tonic.
# ...                                                  ...
# 44686             Plants eaten raw with eulachon grease.
# 44687       Fleshy, whitish rhizomes formerly eaten raw.
# 44688        Leaves formerly used to trap herring spawn.
# 44689  Leaves picked with attached herring spawn and ...
# 44690  Fleshy roots and leaf bases used to flavor sea...
#
#                                                rawsource
# 0      Turner, Nancy J., 1973, The Ethnobotany of the...
# 1      Turner, Nancy J., 1973, The Ethnobotany of the...
# 2      Turner, Nancy J., 1973, The Ethnobotany of the...
# 3      Turner, Nancy J., 1973, The Ethnobotany of the...
# 4      Gottesfeld, Leslie M. J., 1992, The Importance...
# ...                                                  ...
# 44686  Turner, Nancy J., 1973, The Ethnobotany of the...
# 44687  Turner, Nancy J., John Thomas, Barry F. Carlso...
# 44688  Turner, Nancy J., John Thomas, Barry F. Carlso...
# 44689  Compton, Brian Douglas, 1993, Upper North Waka...
# 44690  Turner, Nancy Chapman and Marcus A. M. Bell, 1...
#
# [44691 rows x 9 columns]

# %% [markdown]
# Data cleaning
# --

# %%
uses_data.isnull().sum()
# Out:
# id                    0
# species               0
# tribe                 0
# source                0
# pageno                0
# use_category          0
# use_subcategory    3453
# notes                 0
# rawsource             0
# dtype: int64

# %%
for val in uses_data:
    uses_data[val].fillna(0,inplace=True)
uses_data.head(50)
# Out:
#     id  species  tribe  source pageno  use_category  use_subcategory  \
# 0    1        1     21      53    197             2             25.0
# 1    2        1     21      53    197             2             14.0
# 2    3        1     21      53    197             2            123.0
# 3    4        1     21      53    197             2             49.0
# 4    5        1     86     166    152             2             69.0
# 5    6        1     86     166    152             2              0.0
# 6    7        1     86     166    151             1              0.0
# 7    8        1     86      14    173             3             30.0
# 8    9        1     87      14    173             4             51.0
# 9   10        1     88      14    173             2             14.0
# 10  11        1     88      14    173             2             74.0
# 11  12        1     88      14    173             3             32.0
# 12  13        1    112      14    316             2              0.0
# 13  14        1    112      14    316             1              0.0
# 14  15        1    166     101     71             2            110.0
# 15  16        1    166     101     71             2            137.0
# 16  17        1    166     101     71             1             85.0
# 17  18        1    166     101     71             3             28.0
# 18  19        1    166     101     71             3             53.0
# 19  20        1    181      14     68             2             21.0
# 20  21        1    259      10     97             2             21.0
# 21  22        1    259      10     97             2             20.0
# 22  23        1    259      10     97             2             49.0
# 23  24        1    259      10     97             2             49.0
# 24  25        1    259      10     97             2             49.0
# 25  26        1    259      10     97             2              0.0
# 26  27        1    259      10     97             3             53.0
# 27  28        2      1      84    164             2              8.0
# 28  29        2      1      84    164             2              8.0
# 29  30        2      1      84    155             2            129.0
# 30  31        2      1      84    155             2             20.0
# 31  32        2      1      84    163             2              0.0
# 32  33        2      1      84    164             2              0.0
# 33  34        2      7      67    124             2              8.0
# 34  35        2      7      67    124             2             22.0
# 35  36        2      7      67    124             2            104.0
# 36  37        2      7      67    124             2             36.0
# 37  38        2      7      67    124             2            138.0
# 38  39        2      7      67    124             2              0.0
# 39  40        2      8     113    118             2             21.0
# 40  41        2      8     113    118             4             67.0
# 41  42        2      9     150     64             2              3.0
# 42  43        2      9     150     64             2              3.0
# 43  44        2      9     150     64             2            123.0
# 44  45        2     38       4    338             2              6.0
# 45  46        2     38       4    362             2             35.0
# 46  47        2     38       4    350             2              8.0
# 47  48        2     38       4    362             2             78.0
# 48  49        2     38       4    338             2             78.0
# 49  50        2     58      47     21             2             84.0
#
#                                                 notes  \
# 0   Liquid pitch mixed with mountain goat tallow a...
# 1        Infusion of bark taken for stomach ailments.
# 2   Liquid pitch mixed with mountain goat tallow a...
# 3            Infusion of bark taken for tuberculosis.
# 4              Bark and other plants used as a tonic.
# 5          Bark and other plants used for 'sickness.'
# 6                              Cambium used for food.
# 7              Pitch applied to the face of mourners.
# 8   Boughs used as a 'bush sleigh' to pull cargo a...
# 9          Infusion of bark taken for stomach ulcers.
# 10            Infusion of bark taken for hemorrhoids.
# 11        Boughs used to line oolichan ripening pits.
# 12                Decoction of bark used medicinally.
# 13                          Inner bark used for food.
# 14  Infusion of crushed bark, red alder and hemloc...
# 15  Boughs placed in fire and smoke inhaled to pre...
# 16                Hardened pitch chewed for pleasure.
# 17       Long, hard knots used to make halibut hooks.
# 18  Boughs bundled up and used as home air freshen...
# 19  Pitch boiled with grease or pitch and sugar an...
# 20  Pitch taken for colds. If too much balsam pitc...
# 21  Pitch taken for any type of bad disease. If to...
# 22  Decoction of boughs and/or bark taken for tube...
# 23  Pitch taken for tuberculosis. If too much bals...
# 24  Poultice of pitch and buttercup roots used for...
# 25           Decoction of branches taken as medicine.
# 26  Boiled boughs mixed with decoctions of other p...
# 27                      Gum used for 'slight' itches.
# 28                Gum used to make various ointments.
# 29                             Used as an antiseptic.
# 30    Leaves made into pillows and used as a panacea.
# 31  Needles and wood stuffed into pillows and used...
# 32  Needles stuffed into pillows and used for good...
# 33  Poultice of gum applied to open sores, insect ...
# 34  Needles used in a sudatory for women after chi...
# 35                      Roots used for heart disease.
# 36               Needles used to make a laxative tea.
# 37                 Needles used for making poultices.
# 38  Needles used in a sudatory for women after chi...
# 39                              Sap chewed for colds.
# 40             Boughs used as mats on the tent floor.
# 41  Decoction of bark and bark from another plant ...
# 42                        Gum eaten for kidney pains.
# 43             Infusion of sap used for sore throats.
# 44  Gum melted on warm stone and fumes inhaled for...
# 45  Decoction of root used as herbal steam for rhe...
# 46  Gum of plant with bear grease used as an ointm...
# 47  Decoction of root sprinkled on hot stones and ...
# 48  Gum of plant melted on warm stone as herbal st...
# 49             Pitch used for menstrual irregularity.
#
#                                             rawsource
# 0   Turner, Nancy J., 1973, The Ethnobotany of the...
# 1   Turner, Nancy J., 1973, The Ethnobotany of the...
# 2   Turner, Nancy J., 1973, The Ethnobotany of the...
# 3   Turner, Nancy J., 1973, The Ethnobotany of the...
# 4   Gottesfeld, Leslie M. J., 1992, The Importance...
# 5   Gottesfeld, Leslie M. J., 1992, The Importance...
# 6   Gottesfeld, Leslie M. J., 1992, The Importance...
# 7   Compton, Brian Douglas, 1993, Upper North Waka...
# 8   Compton, Brian Douglas, 1993, Upper North Waka...
# 9   Compton, Brian Douglas, 1993, Upper North Waka...
# 10  Compton, Brian Douglas, 1993, Upper North Waka...
# 11  Compton, Brian Douglas, 1993, Upper North Waka...
# 12  Compton, Brian Douglas, 1993, Upper North Waka...
# 13  Compton, Brian Douglas, 1993, Upper North Waka...
# 14  Turner, Nancy J., John Thomas, Barry F. Carlso...
# 15  Turner, Nancy J., John Thomas, Barry F. Carlso...
# 16  Turner, Nancy J., John Thomas, Barry F. Carlso...
# 17  Turner, Nancy J., John Thomas, Barry F. Carlso...
# 18  Turner, Nancy J., John Thomas, Barry F. Carlso...
# 19  Compton, Brian Douglas, 1993, Upper North Waka...
# 20  Turner, Nancy J., Laurence C. Thompson and M. ...
# 21  Turner, Nancy J., Laurence C. Thompson and M. ...
# 22  Turner, Nancy J., Laurence C. Thompson and M. ...
# 23  Turner, Nancy J., Laurence C. Thompson and M. ...
# 24  Turner, Nancy J., Laurence C. Thompson and M. ...
# 25  Turner, Nancy J., Laurence C. Thompson and M. ...
# 26  Turner, Nancy J., Laurence C. Thompson and M. ...
# 27  Rousseau, Jacques, 1947, Ethnobotanique Abenak...
# 28  Rousseau, Jacques, 1947, Ethnobotanique Abenak...
# 29  Rousseau, Jacques, 1947, Ethnobotanique Abenak...
# 30  Rousseau, Jacques, 1947, Ethnobotanique Abenak...
# 31  Rousseau, Jacques, 1947, Ethnobotanique Abenak...
# 32  Rousseau, Jacques, 1947, Ethnobotanique Abenak...
# 33  Black, Meredith Jean, 1980, Algonquin Ethnobot...
# 34  Black, Meredith Jean, 1980, Algonquin Ethnobot...
# 35  Black, Meredith Jean, 1980, Algonquin Ethnobot...
# 36  Black, Meredith Jean, 1980, Algonquin Ethnobot...
# 37  Black, Meredith Jean, 1980, Algonquin Ethnobot...
# 38  Black, Meredith Jean, 1980, Algonquin Ethnobot...
# 39  Raymond, Marcel., 1945, Notes Ethnobotaniques ...
# 40  Raymond, Marcel., 1945, Notes Ethnobotaniques ...
# 41  Rousseau, Jacques, 1946, Notes Sur L'ethnobota...
# 42  Rousseau, Jacques, 1946, Notes Sur L'ethnobota...
# 43  Rousseau, Jacques, 1946, Notes Sur L'ethnobota...
# 44  Densmore, Frances, 1928, Uses of Plants by the...
# 45  Densmore, Frances, 1928, Uses of Plants by the...
# 46  Densmore, Frances, 1928, Uses of Plants by the...
# 47  Densmore, Frances, 1928, Uses of Plants by the...
# 48  Densmore, Frances, 1928, Uses of Plants by the...
# 49  Leighton, Anna L., 1985, Wild Plant Use by the...

# %%
uses_data.isnull().sum() #checking
# Out:
# id                 0
# species            0
# tribe              0
# source             0
# pageno             0
# use_category       0
# use_subcategory    0
# notes              0
# rawsource          0
# dtype: int64

# %%
# Checking for duplicate values
duplicates = uses_data[uses_data.duplicated(subset='id', keep=False)]
if not duplicates.empty:
    print("Duplicate np_id values found:")
    print(duplicates)
else:
    print("No duplicate np_id values found.")
# Out:
# No duplicate np_id values found.

# %% [markdown]
# Data formatting
# --

# %%
uses_data.columns = [col.strip().lower() for col in uses_data.columns] #keeping column names standard

# %%
uses_data.columns
# Out:
# Index(['id', 'species', 'tribe', 'source', 'pageno', 'use_category',
#        'use_subcategory', 'notes', 'rawsource'],
#       dtype='object')

# %%
uses_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               44691 non-null  int64
#  1   species          44691 non-null  int64
#  2   tribe            44691 non-null  int64
#  3   source           44691 non-null  int64
#  4   pageno           44691 non-null  object
#  5   use_category     44691 non-null  int64
#  6   use_subcategory  44691 non-null  float64
#  7   notes            44691 non-null  object
#  8   rawsource        44691 non-null  object
# dtypes: float64(1), int64(5), object(3)
# memory usage: 3.1+ MB

# %%
uses_data['use_subcategory'] = uses_data['use_subcategory'].astype(int)

# %%
uses_data
# Out:
#           id  species  tribe  source pageno  use_category  use_subcategory  \
# 0          1        1     21      53    197             2               25
# 1          2        1     21      53    197             2               14
# 2          3        1     21      53    197             2              123
# 3          4        1     21      53    197             2               49
# 4          5        1     86     166    152             2               69
# ...      ...      ...    ...     ...    ...           ...              ...
# 44686  44687     4260    122      53    200             1                0
# 44687  44688     4260    166     101     89             1                0
# 44688  44689     4260    166     101     89             3               28
# 44689  44690     4260    181      14     82             1                0
# 44690  44691     4260    215      23     77             1               86
#
#                                                    notes  \
# 0      Liquid pitch mixed with mountain goat tallow a...
# 1           Infusion of bark taken for stomach ailments.
# 2      Liquid pitch mixed with mountain goat tallow a...
# 3               Infusion of bark taken for tuberculosis.
# 4                 Bark and other plants used as a tonic.
# ...                                                  ...
# 44686             Plants eaten raw with eulachon grease.
# 44687       Fleshy, whitish rhizomes formerly eaten raw.
# 44688        Leaves formerly used to trap herring spawn.
# 44689  Leaves picked with attached herring spawn and ...
# 44690  Fleshy roots and leaf bases used to flavor sea...
#
#                                                rawsource
# 0      Turner, Nancy J., 1973, The Ethnobotany of the...
# 1      Turner, Nancy J., 1973, The Ethnobotany of the...
# 2      Turner, Nancy J., 1973, The Ethnobotany of the...
# 3      Turner, Nancy J., 1973, The Ethnobotany of the...
# 4      Gottesfeld, Leslie M. J., 1992, The Importance...
# ...                                                  ...
# 44686  Turner, Nancy J., 1973, The Ethnobotany of the...
# 44687  Turner, Nancy J., John Thomas, Barry F. Carlso...
# 44688  Turner, Nancy J., John Thomas, Barry F. Carlso...
# 44689  Compton, Brian Douglas, 1993, Upper North Waka...
# 44690  Turner, Nancy Chapman and Marcus A. M. Bell, 1...
#
# [44691 rows x 9 columns]

# %% [markdown]
# species
# --

# %%
species_fam_data = pd.read_csv("F:\\MS\\SRH study\\IV sem\\INT\\Datasets 2023\\naeb\\data\\naeb_dump\\species.csv")
species_fam_data
# Out:
#         id                                               name  \
# 0        1  Abies amabilis (Dougl. ex Loud.) Dougl. ex Forbes
# 1        2                       Abies balsamea (L.) P. Mill.
# 2        3  Abies concolor (Gord. & Glend.) Lindl. ex Hild...
# 3        4                        Abies fraseri (Pursh) Poir.
# 4        5            Abies grandis (Dougl. ex D. Don) Lindl.
# ...    ...                                                ...
# 4255  4256                       Zizia aurea (L.) W.D.J. Koch
# 4256  4257  Ziziphus obtusifolia (Hook. ex Torr. & Gray) Gray
# 4257  4258  Ziziphus obtusifolia var. canescens (Gray) M.C...
# 4258  4259                              Ziziphus parryi Torr.
# 4259  4260                                  Zostera marina L.
#
#             common_names usda_code       family   family_apg
# 0     Pacific Silver Fir      ABAM     Pinaceae     Pinaceae
# 1             Balsam Fir      ABBA     Pinaceae     Pinaceae
# 2              White Fir     ABCOC     Pinaceae     Pinaceae
# 3           Fraser's Fir      ABFR     Pinaceae     Pinaceae
# 4              Grand Fir     ABGRG     Pinaceae     Pinaceae
# ...                  ...       ...          ...          ...
# 4255        Golden Zizia      ZIAU     Apiaceae     Apiaceae
# 4256            Lotebush     ZIOBO   Rhamnaceae   Rhamnaceae
# 4257            Lotebush     ZIOBC   Rhamnaceae   Rhamnaceae
# 4258      Parry's Jujube      ZIPA   Rhamnaceae   Rhamnaceae
# 4259            Seawrack      ZOMA  Zosteraceae  Zosteraceae
#
# [4260 rows x 6 columns]

# %%
species_fam_data.isnull().sum()
# Out:
# id                0
# name              0
# common_names    112
# usda_code       499
# family            1
# family_apg      198
# dtype: int64

# %%
for val in species_fam_data:
    species_fam_data[val].fillna('Missing',inplace=True)
species_fam_data.head()
# Out:
#    id                                               name        common_names  \
# 0   1  Abies amabilis (Dougl. ex Loud.) Dougl. ex Forbes  Pacific Silver Fir
# 1   2                       Abies balsamea (L.) P. Mill.          Balsam Fir
# 2   3  Abies concolor (Gord. & Glend.) Lindl. ex Hild...           White Fir
# 3   4                        Abies fraseri (Pursh) Poir.        Fraser's Fir
# 4   5            Abies grandis (Dougl. ex D. Don) Lindl.           Grand Fir
#
#   usda_code    family family_apg
# 0      ABAM  Pinaceae   Pinaceae
# 1      ABBA  Pinaceae   Pinaceae
# 2     ABCOC  Pinaceae   Pinaceae
# 3      ABFR  Pinaceae   Pinaceae
# 4     ABGRG  Pinaceae   Pinaceae

# %%
# Checking for duplicate values
duplicates = species_fam_data[species_fam_data.duplicated(subset='id', keep=False)]
duplicate_count = duplicates['id'].nunique()  # Count unique duplicate np_id values

if not duplicates.empty:
    print("Duplicate np_id values found:")
    print(duplicates)
    print(f"Number of duplicate np_id values: {duplicate_count}")
else:
    print("No duplicate np_id values found.")

# Removing duplicate values
species_fam_data = species_fam_data.drop_duplicates(subset='id', keep='first')

species_fam_data
# Out:
# No duplicate np_id values found.
#         id                                               name  \
# 0        1  Abies amabilis (Dougl. ex Loud.) Dougl. ex Forbes
# 1        2                       Abies balsamea (L.) P. Mill.
# 2        3  Abies concolor (Gord. & Glend.) Lindl. ex Hild...
# 3        4                        Abies fraseri (Pursh) Poir.
# 4        5            Abies grandis (Dougl. ex D. Don) Lindl.
# ...    ...                                                ...
# 4255  4256                       Zizia aurea (L.) W.D.J. Koch
# 4256  4257  Ziziphus obtusifolia (Hook. ex Torr. & Gray) Gray
# 4257  4258  Ziziphus obtusifolia var. canescens (Gray) M.C...
# 4258  4259                              Ziziphus parryi Torr.
# 4259  4260                                  Zostera marina L.
#
#             common_names usda_code       family   family_apg
# 0     Pacific Silver Fir      ABAM     Pinaceae     Pinaceae
# 1             Balsam Fir      ABBA     Pinaceae     Pinaceae
# 2              White Fir     ABCOC     Pinaceae     Pinaceae
# 3           Fraser's Fir      ABFR     Pinaceae     Pinaceae
# 4              Grand Fir     ABGRG     Pinaceae     Pinaceae
# ...                  ...       ...          ...          ...
# 4255        Golden Zizia      ZIAU     Apiaceae     Apiaceae
# 4256            Lotebush     ZIOBO   Rhamnaceae   Rhamnaceae
# 4257            Lotebush     ZIOBC   Rhamnaceae   Rhamnaceae
# 4258      Parry's Jujube      ZIPA   Rhamnaceae   Rhamnaceae
# 4259            Seawrack      ZOMA  Zosteraceae  Zosteraceae
#
# [4260 rows x 6 columns]

# %%
species_fam_data.columns = [col.strip().lower() for col in species_fam_data.columns] #keeping column names standard

# %%
species_fam_data.columns
# Out:
# Index(['id', 'name', 'common_names', 'usda_code', 'family', 'family_apg'], dtype='object')

# %%
species_fam_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4260 entries, 0 to 4259
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            4260 non-null   int64
#  1   name          4260 non-null   object
#  2   common_names  4260 non-null   object
#  3   usda_code     4260 non-null   object
#  4   family        4260 non-null   object
#  5   family_apg    4260 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 233.0+ KB

# %%
species_fam_data
# Out:
#         id                                               name  \
# 0        1  Abies amabilis (Dougl. ex Loud.) Dougl. ex Forbes
# 1        2                       Abies balsamea (L.) P. Mill.
# 2        3  Abies concolor (Gord. & Glend.) Lindl. ex Hild...
# 3        4                        Abies fraseri (Pursh) Poir.
# 4        5            Abies grandis (Dougl. ex D. Don) Lindl.
# ...    ...                                                ...
# 4255  4256                       Zizia aurea (L.) W.D.J. Koch
# 4256  4257  Ziziphus obtusifolia (Hook. ex Torr. & Gray) Gray
# 4257  4258  Ziziphus obtusifolia var. canescens (Gray) M.C...
# 4258  4259                              Ziziphus parryi Torr.
# 4259  4260                                  Zostera marina L.
#
#             common_names usda_code       family   family_apg
# 0     Pacific Silver Fir      ABAM     Pinaceae     Pinaceae
# 1             Balsam Fir      ABBA     Pinaceae     Pinaceae
# 2              White Fir     ABCOC     Pinaceae     Pinaceae
# 3           Fraser's Fir      ABFR     Pinaceae     Pinaceae
# 4              Grand Fir     ABGRG     Pinaceae     Pinaceae
# ...                  ...       ...          ...          ...
# 4255        Golden Zizia      ZIAU     Apiaceae     Apiaceae
# 4256            Lotebush     ZIOBO   Rhamnaceae   Rhamnaceae
# 4257            Lotebush     ZIOBC   Rhamnaceae   Rhamnaceae
# 4258      Parry's Jujube      ZIPA   Rhamnaceae   Rhamnaceae
# 4259            Seawrack      ZOMA  Zosteraceae  Zosteraceae
#
# [4260 rows x 6 columns]

# %% [markdown]
# Tribes
# --

# %%
tribes_data = pd.read_csv('F:\\MS\\SRH study\\IV sem\\INT\\Datasets 2023\\naeb\\data\\naeb_dump\\tribes.csv')
tribes_data.head()
# Out:
#    id           name
# 0   1         Abnaki
# 1   2          Acoma
# 2   3        Alabama
# 3   4  Alaska Native
# 4   5          Aleut

# %%
tribes_data.isnull().sum()
# Out:
# id      0
# name    0
# dtype: int64

# %%
tribes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291 entries, 0 to 290
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      291 non-null    int64
#  1   name    291 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 4.7+ KB

# %%
# Checking for duplicate values
duplicates = tribes_data[tribes_data.duplicated(subset='id', keep=False)]
duplicate_count = duplicates['id'].nunique()  # Count unique duplicate np_id values

if not duplicates.empty:
    print("Duplicate id values found:")
    print(duplicates)
    print(f"Number of duplicate id values: {duplicate_count}")
else:
    print("No duplicate id values found.")
# Out:
# No duplicate id values found.

# %%
tribes_data.columns = [col.strip().lower() for col in tribes_data.columns] #keeping column names standard

# %%
tribes_data.columns
# Out:
# Index(['id', 'name'], dtype='object')

# %%
tribes_data
# Out:
#       id                           name
# 0      1                         Abnaki
# 1      2                          Acoma
# 2      3                        Alabama
# 3      4                  Alaska Native
# 4      5                          Aleut
# ..   ...                            ...
# 286  287                           Yuki
# 287  288                           Yuma
# 288  289                          Yurok
# 289  290  Yurok, South Coast (Nererner)
# 290  291                           Zuni
#
# [291 rows x 2 columns]

# %% [markdown]
# use_categories
# --

# %%
use_categories_data = pd.read_csv('F:\\MS\\SRH study\\IV sem\\INT\\Datasets 2023\\naeb\\data\\naeb_dump\\use_categories.csv')
use_categories_data.head()
# Out:
#    id   name
# 0   1   Food
# 1   2   Drug
# 2   3  Other
# 3   4  Fiber
# 4   5    Dye

# %%
use_categories_data.isnull().sum()
# Out:
# id      0
# name    0
# dtype: int64

# %%
use_categories_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5 non-null      int64
#  1   name    5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
# Checking for duplicate values
duplicates = use_categories_data[use_categories_data.duplicated(subset='id', keep=False)]
duplicate_count = duplicates['id'].nunique()  # Count unique duplicate np_id values

if not duplicates.empty:
    print("Duplicate id values found:")
    print(duplicates)
    print(f"Number of duplicate id values: {duplicate_count}")
else:
    print("No duplicate id values found.")
# Out:
# No duplicate id values found.

# %%
use_categories_data.columns = [col.strip().lower() for col in use_categories_data.columns] #keeping column names standard

# %%
use_categories_data.columns
# Out:
# Index(['id', 'name'], dtype='object')

# %%
use_categories_data
# Out:
#    id   name
# 0   1   Food
# 1   2   Drug
# 2   3  Other
# 3   4  Fiber
# 4   5    Dye

# %% [markdown]
# Targets Information
# --

# %%
use_subcategories_data = pd.read_csv('F:\\MS\\SRH study\\IV sem\\INT\\Datasets 2023\\naeb\\data\\naeb_dump\\use_subcategories.csv')
use_subcategories_data.head()
# Out:
#    id  parent          name
# 0   1       1     Preserves
# 1   2       1  Bread & Cake
# 2   3       2    Kidney Aid
# 3   4       1    Dried Food
# 4   5       1        Forage

# %%
use_subcategories_data.isnull().sum()
# Out:
# id        0
# parent    0
# name      0
# dtype: int64

# %%
use_subcategories_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      389 non-null    int64
#  1   parent  389 non-null    int64
#  2   name    389 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 9.2+ KB

# %%
duplicates = use_subcategories_data[use_subcategories_data.duplicated(subset='id', keep=False)]
duplicate_count = duplicates['id'].nunique()  # Count unique duplicate np_id values

if not duplicates.empty:
    print("Duplicate id values found:")
    print(duplicates)
    print(f"Number of duplicate id values: {duplicate_count}")
else:
    print("No duplicate id values found.")
# Out:
# No duplicate id values found.

# %%
use_subcategories_data.columns = [col.strip().lower() for col in use_subcategories_data.columns] #keeping column names standard

# %%
use_subcategories_data.columns
# Out:
# Index(['id', 'parent', 'name'], dtype='object')

# %%
use_subcategories_data
# Out:
#       id  parent          name
# 0      1       1     Preserves
# 1      2       1  Bread & Cake
# 2      3       2    Kidney Aid
# 3      4       1    Dried Food
# 4      5       1        Forage
# ..   ...     ...           ...
# 384  385       3  Preservative
# 385  386       3  Preservative
# 386  387       2   Dietary Aid
# 387  388       2   Dietary Aid
# 388  389       2   Dietary Aid
#
# [389 rows x 3 columns]

# %% [markdown]
# sources
# --

# %%
sources_book_data = pd.read_csv('F:\\MS\\SRH study\\IV sem\\INT\\Datasets 2023\\naeb\\data\\naeb_dump\\sources.csv')
sources_book_data.head()
# Out:
#    id refcode       type                                           fulltext  \
# 0   1    hc75       book  Hamel, Paul B. and Mary U. Chiltoskey, 1975, C...
# 1   2    ws85       book  Weber, Steven A. and P. David Seaman, 1985, Ha...
# 2   3     g83  phdthesis  Gill, Steven J., 1983, Ethnobotany of the Maka...
# 3   4     d28    article  Densmore, Frances, 1928, Uses of Plants by the...
# 4   5     r54       book  Romero, John Bruno, 1954, The Botanical Lore o...
#
#        address                                 author booktitle comment  \
# 0  Sylva, N.C.  Hamel, Paul B. and Mary U. Chiltoskey       NaN     NaN
# 1       Tucson   Weber, Steven A. and P. David Seaman       NaN     NaN
# 2          NaN                        Gill, Steven J.       NaN     NaN
# 3          NaN                      Densmore, Frances       NaN     NaN
# 4     New York                     Romero, John Bruno       NaN     NaN
#
#   edition editor  ... month note number    pages  \
# 0     NaN    NaN  ...   NaN  NaN    NaN      NaN
# 1     NaN    NaN  ...   NaN  NaN    NaN      NaN
# 2     NaN    NaN  ...   NaN  NaN    NaN      NaN
# 3     NaN    NaN  ...   NaN  NaN    NaN  273-379
# 4     NaN    NaN  ...   NaN  NaN    NaN      NaN
#
#                          publisher                       school  \
# 0             Herald Publishing Co                          NaN
# 1  The University of Arizona Press                          NaN
# 2                              NaN  Washington State University
# 3                              NaN                          NaN
# 4               Vantage Press, Inc                          NaN
#
#                                                title  url volume  year
# 0  Cherokee Plants and Their Uses -- A 400 Year H...  NaN    NaN  1975
# 1  Havasupai Habitat: A.F. Whiting's Ethnography ...  NaN    NaN  1985
# 2         Ethnobotany of the Makah and Ozette People  NaN    NaN  1983
# 3             Uses of Plants by the Chippewa Indians  NaN     44  1928
# 4       The Botanical Lore of the California Indians  NaN    NaN  1954
#
# [5 rows x 21 columns]

# %%
sources_book_data.isnull().sum()
# Out:
# id             0
# refcode        0
# type           0
# fulltext       0
# address      154
# author         0
# booktitle    204
# comment      205
# edition      204
# editor       205
# journal       68
# month        205
# note         197
# number       170
# pages         91
# publisher    151
# school       195
# title          0
# url          204
# volume        73
# year           0
# dtype: int64

# %%
sources_book_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         206 non-null    int64
#  1   refcode    206 non-null    object
#  2   type       206 non-null    object
#  3   fulltext   206 non-null    object
#  4   address    52 non-null     object
#  5   author     206 non-null    object
#  6   booktitle  2 non-null      object
#  7   comment    1 non-null      object
#  8   edition    2 non-null      object
#  9   editor     1 non-null      object
#  10  journal    138 non-null    object
#  11  month      1 non-null      object
#  12  note       9 non-null      object
#  13  number     36 non-null     float64
#  14  pages      115 non-null    object
#  15  publisher  55 non-null     object
#  16  school     11 non-null     object
#  17  title      206 non-null    object
#  18  url        2 non-null      object
#  19  volume     133 non-null    object
#  20  year       206 non-null    int64
# dtypes: float64(1), int64(2), object(18)
# memory usage: 33.9+ KB

# %%
for val in sources_book_data:
    sources_book_data[val].fillna('Missing',inplace=True)
sources_book_data.head(50)
# Out:
#     id  refcode       type                                           fulltext  \
# 0    1     hc75       book  Hamel, Paul B. and Mary U. Chiltoskey, 1975, C...
# 1    2     ws85       book  Weber, Steven A. and P. David Seaman, 1985, Ha...
# 2    3      g83  phdthesis  Gill, Steven J., 1983, Ethnobotany of the Maka...
# 3    4      d28    article  Densmore, Frances, 1928, Uses of Plants by the...
# 4    5      r54       book  Romero, John Bruno, 1954, The Botanical Lore o...
# 5    6      s15    article  Stevenson, Matilda Coxe, 1915, Ethnobotany of ...
# 6    7      h77  phdthesis  Herrick, James William, 1977, Iroquois Medical...
# 7    8      r28    article  Reagan, Albert B., 1928, Plants Used by the Bo...
# 8    9      s29    article  Smith, Harlan I., 1929, Materia Medica of the ...
# 9   10    tta90       book  Turner, Nancy J., Laurence C. Thompson and M. ...
# 10  11      c49       book  Curtin, L. S. M., 1949, By the Prophet of the ...
# 11  12    tha41       book  Train, Percy, James R. Henrichs and W. Andrew ...
# 12  13      g05    article  Grinnell, George Bird, 1905, Some Cheyenne Pla...
# 13  14      c93  phdthesis  Compton, Brian Douglas, 1993, Upper North Waka...
# 14  15    gil33       book  Gilmore, Melvin R., 1933, Some Chippewa Uses o...
# 15  16      b84    article  Bocek, Barbara R., 1984, Ethnobotany of Costan...
# 16  17      g19    article  Gilmore, Melvin R., 1919, Uses of Plants by th...
# 17  18      v52    article  Vestal, Paul A., 1952, The Ethnobotany of the ...
# 18  19      c35    article  Castetter, Edward F., 1935, Ethnobiological St...
# 19  20  smith32    article  Smith, Huron H., 1932, Ethnobotany of the Ojib...
# 20  21  smith28    article  Smith, Huron H., 1928, Ethnobotany of the Mesk...
# 21  22      t42       book  Tantaquidgeon, Gladys, 1942, A Study of Delawa...
# 22  23     tb71    article  Turner, Nancy Chapman and Marcus A. M. Bell, 1...
# 23  24      s08    article  Sparkman, Philip S., 1908, The Culture of the ...
# 24  25      g73       book  Gunther, Erna, 1973, Ethnobotany of Western Wa...
# 25  26      h74       book  Hellson, John C., 1974, Ethnobotany of the Bla...
# 26  27     cu35    article  Castetter, Edward F. and Ruth M. Underhill, 19...
# 27  28      c30  phdthesis  Cook, Sarah Louise, 1930, The Ethnobotany of J...
# 28  29      d44    article  Dawson, E. Yale, 1944, Some Ethnobotanical Not...
# 29  30      h92       book  Hart, Jeff, 1992, Montana Native Plants and Ea...
# 30  31     bs72       book  Bean, Lowell John and Katherine Siva Saubel, 1...
# 31  32    tbk80       book  Turner, Nancy J., R. Bouchard and Dorothy I.D....
# 32  33  steed28    article  Steedman, E.V., 1928, The Ethnobotany of the T...
# 33  34      h49    article  Hocking, George M., 1949, From Pokeroot to Pen...
# 34  35    cfh79    article  Chandler, R. Frank, Lois Freeman and Shirley N...
# 35  36      k85       book  Kari, Priscilla Russe, 1985, Upper Tanana Ethn...
# 36  37      w39    article  Whiting, Alfred F., 1939, Ethnobotany of the H...
# 37  38      c11    article  Chamberlin, Ralph V., 1911, The Ethno-Botany o...
# 38  39      g72       book  Grinnell, George Bird, 1972, The Cheyenne Indi...
# 39  40     gl80       book  Goodrich, Jennie and Claudia Lawson, 1980, Kas...
# 40  41     te82       book  Turner, Nancy J. and Barbara S. Efrat, 1982, E...
# 41  42      m09    article  McClintock, Walter, 1909, Medizinal- Und Nutzp...
# 42  43  smith33    article  Smith, Huron H., 1933, Ethnobotany of the Fore...
# 43  44      r32    article  Ray, Verne F., 1932, The Sanpoil and Nespelem:...
# 44  45      r29    article  Reagan, Albert B., 1929, Plants Used by the Wh...
# 45  46     c57i    article  Curtin, L. S. M., 1957, Some Plants Used by th...
# 46  47      l85       book  Leighton, Anna L., 1985, Wild Plant Use by the...
# 47  48      g36    article  Gifford, E. W., 1936, Northeastern and Western...
# 48  49  speck41    article  Speck, Frank G., 1941, A List of Plant Curativ...
# 49  50      f89       book  Fowler, Catherine S., 1989, Willards Z. Park's...
#
#                                   address  \
# 0                             Sylva, N.C.
# 1                                  Tucson
# 2                                 Missing
# 3                                 Missing
# 4                                New York
# 5                                 Missing
# 6                                 Missing
# 7                                 Missing
# 8                                 Missing
# 9                                Victoria
# 10                               Sante Fe
# 11                          Washington DC
# 12                                Missing
# 13                                Missing
# 14                              Ann Arbor
# 15                                Missing
# 16                                Missing
# 17                                Missing
# 18                                Missing
# 19                                Missing
# 20                                Missing
# 21                             Harrisburg
# 22                                Missing
# 23                                Missing
# 24                             Washington
# 25                                 Ottawa
# 26                                Missing
# 27                                Missing
# 28                                Missing
# 29                                 Helena
# 30                            Banning, CA
# 31                               Victoria
# 32                                Missing
# 33                                Missing
# 34                                Missing
# 35                              Anchorage
# 36                                Missing
# 37                                Missing
# 38                                Lincoln
# 39  University of California, Los Angeles
# 40                               Victoria
# 41                                Missing
# 42                                Missing
# 43                                Missing
# 44                                Missing
# 45                                Missing
# 46                                 Ottawa
# 47                                Missing
# 48                                Missing
# 49                         Salt Lake City
#
#                                                author booktitle  comment  \
# 0               Hamel, Paul B. and Mary U. Chiltoskey   Missing  Missing
# 1                Weber, Steven A. and P. David Seaman   Missing  Missing
# 2                                     Gill, Steven J.   Missing  Missing
# 3                                   Densmore, Frances   Missing  Missing
# 4                                  Romero, John Bruno   Missing  Missing
# 5                             Stevenson, Matilda Coxe   Missing  Missing
# 6                              Herrick, James William   Missing  Missing
# 7                                   Reagan, Albert B.   Missing  Missing
# 8                                    Smith, Harlan I.   Missing  Missing
# 9   Turner, Nancy J. and Laurence C. Thompson and ...   Missing  Missing
# 10                                   Curtin, L. S. M.   Missing  Missing
# 11  Train, Percy and James R. Henrichs and W. Andr...   Missing  Missing
# 12                              Grinnell, George Bird   Missing  Missing
# 13                             Compton, Brian Douglas   Missing  Missing
# 14                                 Gilmore, Melvin R.   Missing  Missing
# 15                                  Bocek, Barbara R.   Missing  Missing
# 16                                 Gilmore, Melvin R.   Missing  Missing
# 17                                    Vestal, Paul A.   Missing  Missing
# 18                               Castetter, Edward F.   Missing  Missing
# 19                                    Smith, Huron H.   Missing  Missing
# 20                                    Smith, Huron H.   Missing  Missing
# 21                              Tantaquidgeon, Gladys   Missing  Missing
# 22        Turner, Nancy Chapman and Marcus A. M. Bell   Missing  Missing
# 23                                Sparkman, Philip S.   Missing  Missing
# 24                                      Gunther, Erna   Missing  Missing
# 25                                   Hellson, John C.   Missing  Missing
# 26         Castetter, Edward F. and Ruth M. Underhill   Missing  Missing
# 27                                 Cook, Sarah Louise   Missing  Missing
# 28                                    Dawson, E. Yale   Missing  Missing
# 29                                         Hart, Jeff   Missing  Missing
# 30        Bean, Lowell John and Katherine Siva Saubel   Missing  Missing
# 31  Turner, Nancy J. and R. Bouchard and Dorothy I...   Missing  Missing
# 32                                    Steedman, E. V.   Missing  Missing
# 33                                 Hocking, George M.   Missing  Missing
# 34  Chandler, R. Frank and Lois Freeman and Shirle...   Missing  Missing
# 35                              Kari, Priscilla Russe   Missing  Missing
# 36                                 Whiting, Alfred F.   Missing  Missing
# 37                               Chamberlin, Ralph V.   Missing  Missing
# 38                              Grinnell, George Bird   Missing  Missing
# 39                Goodrich, Jennie and Claudia Lawson   Missing  Missing
# 40              Turner, Nancy J. and Barbara S. Efrat   Missing  Missing
# 41                                 McClintock, Walter   Missing  Missing
# 42                                    Smith, Huron H.   Missing  Missing
# 43                                      Ray, Verne F.   Missing  Missing
# 44                                  Reagan, Albert B.   Missing  Missing
# 45                                   Curtin, L. S. M.   Missing  Missing
# 46                                  Leighton, Anna L.   Missing  Missing
# 47                                     Gifford, E. W.   Missing  Missing
# 48                                    Speck, Frank G.   Missing  Missing
# 49                               Fowler, Catherine S.   Missing  Missing
#
#     edition   editor  ...     month            note   number            pages  \
# 0   Missing  Missing  ...   Missing         Missing  Missing          Missing
# 1   Missing  Missing  ...   Missing         Missing  Missing          Missing
# 2   Missing  Missing  ...   Missing         Missing  Missing          Missing
# 3   Missing  Missing  ...   Missing         Missing  Missing          273-379
# 4   Missing  Missing  ...   Missing         Missing  Missing          Missing
# 5   Missing  Missing  ...   Missing         Missing  Missing          Missing
# 6   Missing  Missing  ...   Missing         Missing  Missing          Missing
# 7   Missing  Missing  ...   Missing         Missing      4.0          230-248
# 8   Missing  Missing  ...   Missing         Missing  Missing            47-68
# 9   Missing  Missing  ...   Missing         Missing  Missing          Missing
# 10  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 11  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 12  Missing  Missing  ...   Missing         Missing  Missing            37-43
# 13  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 14  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 15  Missing  Missing  ...   Missing         Missing      2.0          240-255
# 16  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 17  Missing  Missing  ...   Missing         Missing      4.0             1-94
# 18  Missing  Missing  ...   Missing         Missing      1.0             1-44
# 19  Missing  Missing  ...   Missing         Missing  Missing          327-525
# 20  Missing  Missing  ...   Missing         Missing  Missing          175-326
# 21  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 22  Missing  Missing  ...   Missing         Missing      1.0  63-104, 335-339
# 23  Missing  Missing  ...   Missing         Missing      4.0          187-234
# 24  Revised  Missing  ...   Missing         Missing  Missing          Missing
# 25  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 26  Missing  Missing  ...   Missing         Missing      3.0             1-84
# 27  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 28  Missing  Missing  ...   Missing         Missing  Missing          133-138
# 29  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 30  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 31  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 32  Missing  Missing  ...   Missing         Missing  Missing          441-522
# 33  Missing  Missing  ...  November         Missing  Missing            12,38
# 34  Missing  Missing  ...   Missing         Missing  Missing            49-68
# 35  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 36  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 37  Missing  Missing  ...   Missing         Missing      5.0          331-405
# 38  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 39  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 40  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 41  Missing  Missing  ...   Missing         Missing  Missing            273-9
# 42  Missing  Missing  ...   Missing         Missing  Missing            1-230
# 43  Missing  Missing  ...   Missing         Missing  Missing          Missing
# 44  Missing  Missing  ...   Missing         Missing  Missing           143-61
# 45  Missing  Missing  ...   Missing         Missing  Missing            40-48
# 46  Missing  Missing  ...   Missing  Mercury Series  Missing          Missing
# 47  Missing  Missing  ...   Missing         Missing  Missing          247-345
# 48  Missing  Missing  ...   Missing         Missing  Missing            49-75
# 49  Missing  Missing  ...   Missing         Missing  Missing          Missing
#
#                                      publisher  \
# 0                         Herald Publishing Co
# 1              The University of Arizona Press
# 2                                      Missing
# 3                                      Missing
# 4                           Vantage Press, Inc
# 5                                      Missing
# 6                                      Missing
# 7                                      Missing
# 8                                      Missing
# 9                Royal British Columbia Museum
# 10                      San Vicente Foundation
# 11              U.S. Department of Agriculture
# 12                                     Missing
# 13                                     Missing
# 14                University of Michigan Press
# 15                                     Missing
# 16                                     Missing
# 17                                     Missing
# 18                                     Missing
# 19                                     Missing
# 20                                     Missing
# 21          Pennsylvania Historical Commission
# 22                                     Missing
# 23                                     Missing
# 24                         University of Press
# 25  National Museums of Canada. Mercury Series
# 26                                     Missing
# 27                                     Missing
# 28                                     Missing
# 29            Montana Historical Society Press
# 30                          Malki Museum Press
# 31          British Columbia Provincial Museum
# 32                                     Missing
# 33                                     Missing
# 34                                     Missing
# 35                Alaska Historical Commission
# 36                                     Missing
# 37                                     Missing
# 38                University of Nebraska Press
# 39              American Indian Studies Center
# 40          British Columbia Provincial Museum
# 41                                     Missing
# 42                                     Missing
# 43                                     Missing
# 44                                     Missing
# 45                                     Missing
# 46                  National Museums of Canada
# 47                                     Missing
# 48                                     Missing
# 49                    University of Utah Press
#
#                                   school  \
# 0                                Missing
# 1                                Missing
# 2            Washington State University
# 3                                Missing
# 4                                Missing
# 5                                Missing
# 6   State University of New York, Albany
# 7                                Missing
# 8                                Missing
# 9                                Missing
# 10                               Missing
# 11                               Missing
# 12                               Missing
# 13        University of British Columbia
# 14                               Missing
# 15                               Missing
# 16                               Missing
# 17                               Missing
# 18                               Missing
# 19                               Missing
# 20                               Missing
# 21                               Missing
# 22                               Missing
# 23                               Missing
# 24                               Missing
# 25                               Missing
# 26                               Missing
# 27              University of New Mexico
# 28                               Missing
# 29                               Missing
# 30                               Missing
# 31                               Missing
# 32                               Missing
# 33                               Missing
# 34                               Missing
# 35                               Missing
# 36                               Missing
# 37                               Missing
# 38                               Missing
# 39                               Missing
# 40                               Missing
# 41                               Missing
# 42                               Missing
# 43                               Missing
# 44                               Missing
# 45                               Missing
# 46                               Missing
# 47                               Missing
# 48                               Missing
# 49                               Missing
#
#                                                 title  \
# 0   Cherokee Plants and Their Uses -- A 400 Year H...
# 1   Havasupai Habitat: A.F. Whiting's Ethnography ...
# 2          Ethnobotany of the Makah and Ozette People
# 3              Uses of Plants by the Chippewa Indians
# 4        The Botanical Lore of the California Indians
# 5                     Ethnobotany of the Zuni Indians
# 6                             Iroquois Medical Botany
# 7   Plants Used by the Bois Fort Chippewa (Ojibwa)...
# 8   Materia Medica of the Bella Coola and Neighbor...
# 9   Thompson Ethnobotany: Knowledge and Usage of P...
# 10  By the Prophet of the Earth: Ethnobotany of th...
# 11  Medicinal Uses of Plants by Indian Tribes of N...
# 12                      Some Cheyenne Plant Medicines
# 13  Upper North Wakashan and Southern Tsimshian Et...
# 14                       Some Chippewa Uses of Plants
# 15  Ethnobotany of Costanoan Indians, California, ...
# 16  Uses of Plants by the Indians of the Missouri ...
# 17                The Ethnobotany of the Ramah Navaho
# 18  Ethnobiological Studies in the American Southw...
# 19                  Ethnobotany of the Ojibwe Indians
# 20                Ethnobotany of the Meskwaki Indians
# 21  A Study of Delaware Indian Medicine Practice a...
# 22  The Ethnobotany of the Coast Salish Indians of...
# 23                 The Culture of the Luiseno Indians
# 24         Ethnobotany of Western Washington, Seattle
# 25               Ethnobotany of the Blackfoot Indians
# 26  Ethnobiological Studies in the American Southw...
# 27                   The Ethnobotany of Jemez Indians
# 28      Some Ethnobotanical Notes on the Seri Indians
# 29            Montana Native Plants and Early Peoples
# 30  Temalpakh (From the Earth); Cahuilla Indian Kn...
# 31  Ethnobotany of the Okanagan-Colville Indians o...
# 32  The Ethnobotany of the Thompson Indians of Bri...
# 33                        From Pokeroot to Penicillin
# 34            Herbal Remedies of the Maritime Indians
# 35                           Upper Tanana Ethnobotany
# 36                            Ethnobotany of the Hopi
# 37    The Ethno-Botany of the Gosiute Indians of Utah
# 38  The Cheyenne Indians - Their History and Ways ...
# 39                   Kashaya Pomo Plants, Los Angeles
# 40  Ethnobotany of the Hesquiat Indians of Vancouv...
# 41  Medizinal- Und Nutzpflanzen Der Schwarzfuss In...
# 42       Ethnobotany of the Forest Potawatomi Indians
# 43  The Sanpoil and Nespelem: Salishan Peoples of ...
# 44  Plants Used by the White Mountain Apache India...
# 45  Some Plants Used by the Yuki Indians ... I. Hi...
# 46  Wild Plant Use by the Woods Cree (Nihithawak) ...
# 47                   Northeastern and Western Yavapai
# 48  A List of Plant Curatives Obtained From the Ho...
# 49  Willards Z. Park's Ethnographic Notes on the N...
#
#                                                   url   volume  year
# 0                                             Missing  Missing  1975
# 1                                             Missing  Missing  1985
# 2                                             Missing  Missing  1983
# 3                                             Missing       44  1928
# 4                                             Missing  Missing  1954
# 5                                             Missing       30  1915
# 6                                             Missing  Missing  1977
# 7                                             Missing        7  1928
# 8                                             Missing       56  1929
# 9                                             Missing  Missing  1990
# 10                                            Missing  Missing  1949
# 11                                            Missing  Missing  1941
# 12                                            Missing        7  1905
# 13                                            Missing  Missing  1993
# 14                                            Missing  Missing  1933
# 15                                            Missing       38  1984
# 16                                            Missing       33  1919
# 17                                            Missing       40  1952
# 18  https://digitalrepository.unm.edu/unm_bulletin...        4  1935
# 19                                            Missing        4  1932
# 20                                            Missing        4  1928
# 21                                            Missing  Missing  1942
# 22                 https://doi.org/10.1007/BF02894564       25  1971
# 23                                            Missing        8  1908
# 24                                            Missing  Missing  1973
# 25                                            Missing  Missing  1974
# 26                                            Missing        4  1935
# 27                                            Missing  Missing  1930
# 28                                            Missing        9  1944
# 29                                            Missing  Missing  1992
# 30                                            Missing  Missing  1972
# 31                                            Missing  Missing  1980
# 32                                            Missing       45  1928
# 33                                            Missing  Missing  1949
# 34                                            Missing        1  1979
# 35                                            Missing  Missing  1985
# 36                                            Missing       15  1939
# 37                                            Missing        2  1911
# 38                                            Missing  Missing  1972
# 39                                            Missing  Missing  1980
# 40                                            Missing  Missing  1982
# 41                                            Missing       41  1909
# 42                                            Missing        7  1933
# 43                                            Missing        5  1932
# 44                                            Missing        8  1929
# 45                                            Missing       31  1957
# 46                                            Missing  Missing  1985
# 47                                            Missing       34  1936
# 48                                            Missing       14  1941
# 49                                            Missing  Missing  1989
#
# [50 rows x 21 columns]

# %%
sources_book_data.isnull().sum() #checking
# Out:
# id           0
# refcode      0
# type         0
# fulltext     0
# address      0
# author       0
# booktitle    0
# comment      0
# edition      0
# editor       0
# journal      0
# month        0
# note         0
# number       0
# pages        0
# publisher    0
# school       0
# title        0
# url          0
# volume       0
# year         0
# dtype: int64

# %%
duplicates = sources_book_data[sources_book_data.duplicated(subset='id', keep=False)]
duplicate_count = duplicates['id'].nunique()  # Count unique duplicate np_id values

if not duplicates.empty:
    print("Duplicate id values found:")
    print(duplicates)
    print(f"Number of duplicate id values: {duplicate_count}")
else:
    print("No duplicate id values found.")
# Out:
# No duplicate id values found.

# %%
sources_book_data.columns = [col.strip().lower() for col in sources_book_data.columns] #keeping column names standard

# %%
sources_book_data.columns
# Out:
# Index(['id', 'refcode', 'type', 'fulltext', 'address', 'author', 'booktitle',
#        'comment', 'edition', 'editor', 'journal', 'month', 'note', 'number',
#        'pages', 'publisher', 'school', 'title', 'url', 'volume', 'year'],
#       dtype='object')

# %%
sources_book_data
# Out:
#       id refcode       type  \
# 0      1    hc75       book
# 1      2    ws85       book
# 2      3     g83  phdthesis
# 3      4     d28    article
# 4      5     r54       book
# ..   ...     ...        ...
# 201  202     b36    article
# 202  203     r23    article
# 203  204     w89    article
# 204  205     p37       book
# 205  206     m40    article
#
#                                               fulltext      address  \
# 0    Hamel, Paul B. and Mary U. Chiltoskey, 1975, C...  Sylva, N.C.
# 1    Weber, Steven A. and P. David Seaman, 1985, Ha...       Tucson
# 2    Gill, Steven J., 1983, Ethnobotany of the Maka...      Missing
# 3    Densmore, Frances, 1928, Uses of Plants by the...      Missing
# 4    Romero, John Bruno, 1954, The Botanical Lore o...     New York
# ..                                                 ...          ...
# 201  Bradley, Will T., 1936, Medical Practices of t...      Missing
# 202  Radin, Paul, 1923, The Winnebago Tribe, SI-BAE...      Missing
# 203  Willoughby, C., 1889, Indians of the Quinaielt...      Missing
# 204  Porsild, A.E., 1937, Edible Roots and Berries ...      Missing
# 205  Mandelbaum, David G., 1940, The Plains Cree, A...      Missing
#
#                                     author booktitle  comment  edition  \
# 0    Hamel, Paul B. and Mary U. Chiltoskey   Missing  Missing  Missing
# 1     Weber, Steven A. and P. David Seaman   Missing  Missing  Missing
# 2                          Gill, Steven J.   Missing  Missing  Missing
# 3                        Densmore, Frances   Missing  Missing  Missing
# 4                       Romero, John Bruno   Missing  Missing  Missing
# ..                                     ...       ...      ...      ...
# 201                       Bradley, Will T.   Missing  Missing  Missing
# 202                            Radin, Paul   Missing  Missing  Missing
# 203                         Willoughby, C.   Missing  Missing  Missing
# 204                         Porsild, A. E.   Missing  Missing  Missing
# 205                   Mandelbaum, David G.   Missing  Missing  Missing
#
#       editor  ...    month     note   number    pages  \
# 0    Missing  ...  Missing  Missing  Missing  Missing
# 1    Missing  ...  Missing  Missing  Missing  Missing
# 2    Missing  ...  Missing  Missing  Missing  Missing
# 3    Missing  ...  Missing  Missing  Missing  273-379
# 4    Missing  ...  Missing  Missing  Missing  Missing
# ..       ...  ...      ...      ...      ...      ...
# 201  Missing  ...  Missing  Missing      2.0  138-147
# 202  Missing  ...  Missing  Missing  Missing  Missing
# 203  Missing  ...  Missing  Missing  Missing  Missing
# 204  Missing  ...  Missing  Missing  Missing  Missing
# 205  Missing  ...  Missing  Missing  Missing  202-203
#
#                                              publisher  \
# 0                                 Herald Publishing Co
# 1                      The University of Arizona Press
# 2                                              Missing
# 3                                              Missing
# 4                                   Vantage Press, Inc
# ..                                                 ...
# 201                                            Missing
# 202                                            Missing
# 203                                            Missing
# 204  Canada Department of Mines and Resources, Nati...
# 205                                            Missing
#
#                           school  \
# 0                        Missing
# 1                        Missing
# 2    Washington State University
# 3                        Missing
# 4                        Missing
# ..                           ...
# 201                      Missing
# 202                      Missing
# 203                      Missing
# 204                      Missing
# 205                      Missing
#
#                                                  title      url   volume  year
# 0    Cherokee Plants and Their Uses -- A 400 Year H...  Missing  Missing  1975
# 1    Havasupai Habitat: A.F. Whiting's Ethnography ...  Missing  Missing  1985
# 2           Ethnobotany of the Makah and Ozette People  Missing  Missing  1983
# 3               Uses of Plants by the Chippewa Indians  Missing       44  1928
# 4         The Botanical Lore of the California Indians  Missing  Missing  1954
# ..                                                 ...      ...      ...   ...
# 201    Medical Practices of the New England Aborigines  Missing       25  1936
# 202                                The Winnebago Tribe  Missing       37  1923
# 203  Indians of the Quinaielt Agency, Washington Te...  Missing  Missing  1889
# 204        Edible Roots and Berries of Northern Canada  Missing  Missing  1937
# 205                                    The Plains Cree  Missing       37  1940
#
# [206 rows x 21 columns]

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in d:\softwares\r-4.2.1\anaconda\lib\site-packages (2.9.9)Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

connection = psycopg2.connect(
    host="localhost",
    database="compound",
    user="postgres",
    password="123456"
)

engine = create_engine('postgresql://postgres:123456@localhost/compound')

uses_data.to_sql('naeb_uses_table', engine, if_exists='replace', index=False)
species_fam_data.to_sql('naeb_species_fam_table', engine, if_exists='replace', index=False)
tribes_data.to_sql('naeb_tribes_table', engine, if_exists='replace', index=False)
use_categories_data.to_sql('naeb_use_categories_table', engine, if_exists='replace', index=False)
use_subcategories_data.to_sql('naeb_use_subcategories_table', engine, if_exists='replace', index=False)
sources_book_data.to_sql('naeb_sources_book_table', engine, if_exists='replace', index=False)

connection.close()

print("DataFrame successfully written to PostgreSQL table.")
# Out:
# DataFrame successfully written to PostgreSQL table.
